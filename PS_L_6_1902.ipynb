# %% [markdown]
# <a href="https://colab.research.google.com/github/MeherNaaz19/PS-2025/blob/main/PS_L_6_1902.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  **NORMAL DISTRIBUTION**

# %% [markdown]
# # Question-1

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
# Generating a normal distribution of data points
mean = 75
std_dev = 10
data = np.random.normal(mean, std_dev, 1000)

# %%
#Calculating the PDF
x=np.linspace(mean-3*std_dev,mean+3*std_dev,1000)
pdf=norm.pdf(x,mean,std_dev)

# %%
plt.figure(figsize=(10,6))
plt.hist(data,bins=30,density=True,alpha=0.6,color='blue')
plt.plot(x,pdf,'r-',lw=2)
plt.title("Histogram and PDF of Normal Distribution (mean = 75, std_dev = 10)")
plt.xlabel("Value")
plt.ylabel("Density")
plt.show()

# %% [markdown]
# # Question-2

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# %%
def calculate_probabilities(IQ1,IQ2):
  mean=20
  std_dev=4
  p_ge_bmi1=1-stats.norm.cdf(bmi1,mean,std_dev)#Calculating probabilities
  p_le_bmi1=stats.norm.cdf(bmi1,mean,std_dev)
  p_between_bmi1_bmi2=stats.norm.cdf(bmi2,mean,std_dev)-stats.norm.cdf(bmi1,mean,std_dev)
  print(f"P(X>={bmi1})={p_ge_bmi1:.4f}")#print probabilities
  print(f"P(X<={bmi2})={p_le_bmi1:.4f}")
  print(f"P({bmi1}<= X <= {bmi2})={p_between_bmi1_bmi2:.4f}")
  x=np.linspace(mean-4*std_dev,mean+4*std_dev,1000)
  y=stats.norm.pdf(x,mean,std_dev)
  plt.plot(x,y,label="Normal Distribution")
  plt.fill_between(x,y,where=(x>=bmi1),color='red',alpha=0.5,label=f"P(X>={bmi1})")
  plt.fill_between(x,y,where=(x<=bmi1),color='blue',alpha=0.5,label=f"P(X<={bmi1})")
  plt.fill_between(x,y,where=(x>=bmi1) & (x<=bmi2),color='green',alpha=0.5,label=f"P({bmi1})<=X<={bmi2}")
  plt.xlabel("BMI")
  plt.ylabel("Probability Density")
  plt.title("Normal Distribution of BMI")
  plt.legend()
  plt.grid(True)
  plt.show()
bmi1=23
bmi2=27
calculate_probabilities(bmi1,bmi2)
# Out:
# P(X>=23)=0.2266
# P(X<=27)=0.7734
# P(23<= X <= 27)=0.1866
