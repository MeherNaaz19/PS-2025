# %% [markdown]
# <a href="https://colab.research.google.com/github/MeherNaaz19/PS-2025/blob/main/PS_L_6_1902.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **NORMAL DISTRIBUTION**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
# Generating a normal distribution of data points
mean = 75
std_dev = 10
data = np.random.normal(mean, std_dev, 1000)

# %%
#Calculating the PDF
x=np.linspace(mean-3*std_dev,mean+3*std_dev,1000)
pdf=norm.pdf(x,mean,std_dev)

# %%
plt.figure(figsize=(10,6))
plt.hist(data,bins=30,density=True,alpha=0.6,color='blue')
plt.plot(x,pdf,'r-',lw=2)
plt.title("Histogram and PDF of Normal Distribution (mean = 75, std_dev = 10)")
plt.xlabel("Value")
plt.ylabel("Density")
plt.show()
